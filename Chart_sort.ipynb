# %% [markdown]
# <a href="https://colab.research.google.com/github/cungryan28/test/blob/main/Chart_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("result.csv")

plt.figure(figsize=(12, 8))

# %% [markdown]
# # Thời gian

# %% [markdown]
# ## Các thuật toán sắp xếp nhanh (Quick sort, Merge sort, Heap sort, Shell sort, Counting sort, Radix sort, Flash sort)

# %%
plt.figure(figsize=(12, 8))
filtered_data_quick = data[
    (data['Algorithm'] == 'quick-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_merge = data[
    (data['Algorithm'] == 'merge-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_heap = data[
    (data['Algorithm'] == 'heap-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_shell = data[
    (data['Algorithm'] == 'shell-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_counting = data[
    (data['Algorithm'] == 'counting-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_radix = data[
    (data['Algorithm'] == 'radix-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_flash = data[
    (data['Algorithm'] == 'flash-sort') & (data['Data Order'] == 'Randomize')
]

# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
quick_sort = filtered_data_quick['Running Time (ms)']
merge_sort = filtered_data_merge['Running Time (ms)']
heap_sort = filtered_data_heap['Running Time (ms)']
shell_sort = filtered_data_shell['Running Time (ms)']
counting_sort = filtered_data_counting['Running Time (ms)']
radix_sort = filtered_data_radix['Running Time (ms)']
flash_sort = filtered_data_flash['Running Time (ms)']

plt.plot(data_size, quick_sort, marker='o', linestyle='-', color='b', label='quick-sort')
plt.plot(data_size, heap_sort, marker='o', linestyle='-', color='r', label='heap-sort')
plt.plot(data_size, merge_sort, marker='o', linestyle='-', color='g', label='merge-sort')
plt.plot(data_size, shell_sort, marker='o', linestyle='-', color='y', label='shell-sort')

plt.plot(data_size, counting_sort, marker='o', linestyle='-', color='black', label='counting-sort')
plt.plot(data_size, radix_sort, marker='o', linestyle='-', color='aqua', label='radix-sort')
plt.plot(data_size, flash_sort, marker='o', linestyle='-', color='pink', label='flash-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu ngẫu nhiên (Randomize)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/time/fast/random.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_quick = data[
    (data['Algorithm'] == 'quick-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_merge = data[
    (data['Algorithm'] == 'merge-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_heap = data[
    (data['Algorithm'] == 'heap-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_shell = data[
    (data['Algorithm'] == 'shell-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_counting = data[
    (data['Algorithm'] == 'counting-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_radix = data[
    (data['Algorithm'] == 'radix-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_flash = data[
    (data['Algorithm'] == 'flash-sort') & (data['Data Order'] == 'Nearly sorted')
]



# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
quick_sort = filtered_data_quick['Running Time (ms)']
merge_sort = filtered_data_merge['Running Time (ms)']
heap_sort = filtered_data_heap['Running Time (ms)']
shell_sort = filtered_data_shell['Running Time (ms)']

counting_sort = filtered_data_counting['Running Time (ms)']
radix_sort = filtered_data_radix['Running Time (ms)']
flash_sort = filtered_data_flash['Running Time (ms)']

plt.plot(data_size, quick_sort, marker='o', linestyle='-', color='b', label='quick-sort')
plt.plot(data_size, heap_sort, marker='o', linestyle='-', color='r', label='heap-sort')
plt.plot(data_size, merge_sort, marker='o', linestyle='-', color='g', label='merge-sort')
plt.plot(data_size, shell_sort, marker='o', linestyle='-', color='y', label='shell-sort')

plt.plot(data_size, counting_sort, marker='o', linestyle='-', color='black', label='counting-sort')
plt.plot(data_size, radix_sort, marker='o', linestyle='-', color='aqua', label='radix-sort')
plt.plot(data_size, flash_sort, marker='o', linestyle='-', color='pink', label='flash-sort')

# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu gần như đã sắp xếp (Nearly sorted)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ
plt.savefig('./img/time/fast/nsorted.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_quick = data[
    (data['Algorithm'] == 'quick-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_merge = data[
    (data['Algorithm'] == 'merge-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_heap = data[
    (data['Algorithm'] == 'heap-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_shell = data[
    (data['Algorithm'] == 'shell-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_counting = data[
    (data['Algorithm'] == 'counting-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_radix = data[
    (data['Algorithm'] == 'radix-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_flash = data[
    (data['Algorithm'] == 'flash-sort') & (data['Data Order'] == 'Sorted')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
quick_sort = filtered_data_quick['Running Time (ms)']
merge_sort = filtered_data_merge['Running Time (ms)']
heap_sort = filtered_data_heap['Running Time (ms)']
shell_sort = filtered_data_shell['Running Time (ms)']

counting_sort = filtered_data_counting['Running Time (ms)']
radix_sort = filtered_data_radix['Running Time (ms)']
flash_sort = filtered_data_flash['Running Time (ms)']

plt.plot(data_size, quick_sort, marker='o', linestyle='-', color='b', label='quick-sort')
plt.plot(data_size, heap_sort, marker='o', linestyle='-', color='r', label='heap-sort')
plt.plot(data_size, merge_sort, marker='o', linestyle='-', color='g', label='merge-sort')
plt.plot(data_size, shell_sort, marker='o', linestyle='-', color='y', label='shell-sort')

plt.plot(data_size, counting_sort, marker='o', linestyle='-', color='black', label='counting-sort')
plt.plot(data_size, radix_sort, marker='o', linestyle='-', color='aqua', label='radix-sort')
plt.plot(data_size, flash_sort, marker='o', linestyle='-', color='pink', label='flash-sort')

# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu đã sắp xếp (Sorted)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ
plt.savefig('./img/time/fast/sorted.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_quick = data[
    (data['Algorithm'] == 'quick-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_merge = data[
    (data['Algorithm'] == 'merge-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_heap = data[
    (data['Algorithm'] == 'heap-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_shell = data[
    (data['Algorithm'] == 'shell-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_counting = data[
    (data['Algorithm'] == 'counting-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_radix = data[
    (data['Algorithm'] == 'radix-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_flash = data[
    (data['Algorithm'] == 'flash-sort') & (data['Data Order'] == 'Reversed')
]

# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
quick_sort = filtered_data_quick['Running Time (ms)']
merge_sort = filtered_data_merge['Running Time (ms)']
heap_sort = filtered_data_heap['Running Time (ms)']
shell_sort = filtered_data_shell['Running Time (ms)']
counting_sort = filtered_data_counting['Running Time (ms)']
radix_sort = filtered_data_radix['Running Time (ms)']
flash_sort = filtered_data_flash['Running Time (ms)']

plt.plot(data_size, quick_sort, marker='o', linestyle='-', color='b', label='quick-sort')
plt.plot(data_size, heap_sort, marker='o', linestyle='-', color='r', label='heap-sort')
plt.plot(data_size, merge_sort, marker='o', linestyle='-', color='g', label='merge-sort')
plt.plot(data_size, shell_sort, marker='o', linestyle='-', color='y', label='shell-sort')

plt.plot(data_size, counting_sort, marker='o', linestyle='-', color='black', label='counting-sort')
plt.plot(data_size, radix_sort, marker='o', linestyle='-', color='aqua', label='radix-sort')
plt.plot(data_size, flash_sort, marker='o', linestyle='-', color='pink', label='flash-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu sắp xếp giảm dần (Reversed)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ
plt.savefig('./img/time/fast/rev.png', dpi=300)
plt.show()

# %% [markdown]
# ## Các thuật toán sắp xếp chậm (Bubble sort, Insertion sort, Selection sort, Shaker sort)

# %%
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Randomize')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Running Time (ms)']
insertion_sort = filtered_data_insertion['Running Time (ms)']
selection_sort = filtered_data_selection['Running Time (ms)']
shaker_sort = filtered_data_shaker['Running Time (ms)']

plt.plot(data_size, bubble_sort, marker='o', linestyle='-', color='b', label='bubble-sort')
plt.plot(data_size, insertion_sort, marker='o', linestyle='-', color='r', label='insertion-sort')
plt.plot(data_size, selection_sort, marker='o', linestyle='-', color='g', label='selection-sort')
plt.plot(data_size, shaker_sort, marker='o', linestyle='-', color='y', label='shaker-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu ngẫu nhiên (Randomize)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/time/slow/random.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Nearly sorted')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Running Time (ms)']
insertion_sort = filtered_data_insertion['Running Time (ms)']
selection_sort = filtered_data_selection['Running Time (ms)']
shaker_sort = filtered_data_shaker['Running Time (ms)']

plt.plot(data_size, bubble_sort, marker='o', linestyle='-', color='b', label='bubble-sort')
plt.plot(data_size, selection_sort, marker='o', linestyle='-', color='g', label='selection-sort')
#plt.plot(data_size, insertion_sort, marker='o', linestyle='-', color='r', label='insertion-sort')
#plt.plot(data_size, shaker_sort, marker='o', linestyle='dashed', color='y', label='shaker-sort')


plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu gần như đã sắp xếp (Nearly sorted)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()

# Hiển thị biểu đồ
plt.savefig('./img/time/slow/nsorted-bubble-selection.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Nearly sorted')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Running Time (ms)']
insertion_sort = filtered_data_insertion['Running Time (ms)']
selection_sort = filtered_data_selection['Running Time (ms)']
shaker_sort = filtered_data_shaker['Running Time (ms)']

#plt.plot(data_size, bubble_sort, marker='o', linestyle='-', color='b', label='bubble-sort')
#plt.plot(data_size, selection_sort, marker='o', linestyle='-', color='g', label='selection-sort')
plt.plot(data_size, insertion_sort, marker='o', linestyle='-', color='r', label='insertion-sort')
plt.plot(data_size, shaker_sort, marker='o', linestyle='-', color='y', label='shaker-sort')


plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu gần như đã sắp xếp (Nearly sorted)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()

# Hiển thị biểu đồ
plt.savefig('./img/time/slow/nsorted-insertion-shaker.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Sorted')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Running Time (ms)']
insertion_sort = filtered_data_insertion['Running Time (ms)']
selection_sort = filtered_data_selection['Running Time (ms)']
shaker_sort = filtered_data_shaker['Running Time (ms)']

plt.plot(data_size, bubble_sort, marker='o', linestyle='-', color='b', label='bubble-sort')
plt.plot(data_size, insertion_sort, marker='o', linestyle='-', color='r', label='insertion-sort')
#plt.plot(data_size, selection_sort, marker='o', linestyle='-', color='g', label='selection-sort')
plt.plot(data_size, shaker_sort, marker='o', linestyle='-', color='y', label='shaker-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu đã sắp xếp (Sorted)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/time/slow/sorted-bubble-insertion-shaker.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Sorted')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Running Time (ms)']
insertion_sort = filtered_data_insertion['Running Time (ms)']
selection_sort = filtered_data_selection['Running Time (ms)']
shaker_sort = filtered_data_shaker['Running Time (ms)']

plt.plot(data_size, selection_sort, marker='o', linestyle='-', color='g', label='selection-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu đã sắp xếp (Sorted)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/time/slow/sorted-selection.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Reversed')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Running Time (ms)']
insertion_sort = filtered_data_insertion['Running Time (ms)']
selection_sort = filtered_data_selection['Running Time (ms)']
shaker_sort = filtered_data_shaker['Running Time (ms)']

plt.plot(data_size, bubble_sort, marker='o', linestyle='-', color='b', label='bubble-sort')
plt.plot(data_size, insertion_sort, marker='o', linestyle='-', color='r', label='insertion-sort')
plt.plot(data_size, selection_sort, marker='o', linestyle='-', color='g', label='selection-sort')
plt.plot(data_size, shaker_sort, marker='o', linestyle='-', color='y', label='shaker-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện thời gian thực thi trên tập dữ liệu sắp xếp giảm dần (Reversed)")
plt.xlabel("Input")
plt.ylabel("Running time (ms)")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/time/slow/rev.png', dpi=300)
plt.show()

# %% [markdown]
# # Số phép so sánh

# %% [markdown]
# ## Các thuật toán sắp xếp nhanh (Quick sort, Merge sort, Heap sort, Shell sort, Counting sort, Radix sort, Flash sort)

# %%
plt.figure(figsize=(12, 8))
filtered_data_quick = data[
    (data['Algorithm'] == 'quick-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_merge = data[
    (data['Algorithm'] == 'merge-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_heap = data[
    (data['Algorithm'] == 'heap-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_shell = data[
    (data['Algorithm'] == 'shell-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_counting = data[
    (data['Algorithm'] == 'counting-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_radix = data[
    (data['Algorithm'] == 'radix-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_flash = data[
    (data['Algorithm'] == 'flash-sort') & (data['Data Order'] == 'Randomize')
]

# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
quick_sort = filtered_data_quick['Comparisons']
merge_sort = filtered_data_merge['Comparisons']
heap_sort = filtered_data_heap['Comparisons']
shell_sort = filtered_data_shell['Comparisons']
counting_sort = filtered_data_counting['Comparisons']
radix_sort = filtered_data_radix['Comparisons']
flash_sort = filtered_data_flash['Comparisons']

plt.plot(data_size, quick_sort, marker='o', linestyle='-', color='b', label='quick-sort')
plt.plot(data_size, heap_sort, marker='o', linestyle='-', color='r', label='heap-sort')
plt.plot(data_size, merge_sort, marker='o', linestyle='-', color='g', label='merge-sort')
plt.plot(data_size, shell_sort, marker='o', linestyle='-', color='y', label='shell-sort')

plt.plot(data_size, counting_sort, marker='o', linestyle='-', color='black', label='counting-sort')
plt.plot(data_size, radix_sort, marker='o', linestyle='-', color='aqua', label='radix-sort')
plt.plot(data_size, flash_sort, marker='o', linestyle='-', color='pink', label='flash-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện số phép so sánh trên tập dữ liệu ngẫu nhiên (Randomize)")
plt.xlabel("Input")
plt.ylabel("Comparisons")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/comparison/fast/random.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_quick = data[
    (data['Algorithm'] == 'quick-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_merge = data[
    (data['Algorithm'] == 'merge-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_heap = data[
    (data['Algorithm'] == 'heap-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_shell = data[
    (data['Algorithm'] == 'shell-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_counting = data[
    (data['Algorithm'] == 'counting-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_radix = data[
    (data['Algorithm'] == 'radix-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_flash = data[
    (data['Algorithm'] == 'flash-sort') & (data['Data Order'] == 'Nearly sorted')
]

# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
quick_sort = filtered_data_quick['Comparisons']
merge_sort = filtered_data_merge['Comparisons']
heap_sort = filtered_data_heap['Comparisons']
shell_sort = filtered_data_shell['Comparisons']
counting_sort = filtered_data_counting['Comparisons']
radix_sort = filtered_data_radix['Comparisons']
flash_sort = filtered_data_flash['Comparisons']

plt.plot(data_size, quick_sort, marker='o', linestyle='-', color='b', label='quick-sort')
plt.plot(data_size, heap_sort, marker='o', linestyle='-', color='r', label='heap-sort')
plt.plot(data_size, merge_sort, marker='o', linestyle='-', color='g', label='merge-sort')
plt.plot(data_size, shell_sort, marker='o', linestyle='-', color='y', label='shell-sort')

plt.plot(data_size, counting_sort, marker='o', linestyle='-', color='black', label='counting-sort')
plt.plot(data_size, radix_sort, marker='o', linestyle='-', color='aqua', label='radix-sort')
plt.plot(data_size, flash_sort, marker='o', linestyle='-', color='pink', label='flash-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện số phép so sánh trên tập dữ liệu gần như đã sắp xếp (Nearly sorted)")
plt.xlabel("Input")
plt.ylabel("Comparisons")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/comparison/fast/nsorted.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_quick = data[
    (data['Algorithm'] == 'quick-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_merge = data[
    (data['Algorithm'] == 'merge-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_heap = data[
    (data['Algorithm'] == 'heap-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_shell = data[
    (data['Algorithm'] == 'shell-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_counting = data[
    (data['Algorithm'] == 'counting-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_radix = data[
    (data['Algorithm'] == 'radix-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_flash = data[
    (data['Algorithm'] == 'flash-sort') & (data['Data Order'] == 'Sorted')
]

# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
quick_sort = filtered_data_quick['Comparisons']
merge_sort = filtered_data_merge['Comparisons']
heap_sort = filtered_data_heap['Comparisons']
shell_sort = filtered_data_shell['Comparisons']
counting_sort = filtered_data_counting['Comparisons']
radix_sort = filtered_data_radix['Comparisons']
flash_sort = filtered_data_flash['Comparisons']

plt.plot(data_size, quick_sort, marker='o', linestyle='-', color='b', label='quick-sort')
plt.plot(data_size, heap_sort, marker='o', linestyle='-', color='r', label='heap-sort')
plt.plot(data_size, merge_sort, marker='o', linestyle='-', color='g', label='merge-sort')
plt.plot(data_size, shell_sort, marker='o', linestyle='-', color='y', label='shell-sort')

plt.plot(data_size, counting_sort, marker='o', linestyle='-', color='black', label='counting-sort')
plt.plot(data_size, radix_sort, marker='o', linestyle='-', color='aqua', label='radix-sort')
plt.plot(data_size, flash_sort, marker='o', linestyle='-', color='pink', label='flash-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện số phép so sánh trên tập dữ liệu đã sắp xếp (Sorted)")
plt.xlabel("Input")
plt.ylabel("Comparisons")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/comparison/fast/sorted.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(12, 8))
filtered_data_quick = data[
    (data['Algorithm'] == 'quick-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_merge = data[
    (data['Algorithm'] == 'merge-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_heap = data[
    (data['Algorithm'] == 'heap-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_shell = data[
    (data['Algorithm'] == 'shell-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_counting = data[
    (data['Algorithm'] == 'counting-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_radix = data[
    (data['Algorithm'] == 'radix-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_flash = data[
    (data['Algorithm'] == 'flash-sort') & (data['Data Order'] == 'Reversed')
]

# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
quick_sort = filtered_data_quick['Comparisons']
merge_sort = filtered_data_merge['Comparisons']
heap_sort = filtered_data_heap['Comparisons']
shell_sort = filtered_data_shell['Comparisons']
counting_sort = filtered_data_counting['Comparisons']
radix_sort = filtered_data_radix['Comparisons']
flash_sort = filtered_data_flash['Comparisons']

plt.plot(data_size, quick_sort, marker='o', linestyle='-', color='b', label='quick-sort')
plt.plot(data_size, heap_sort, marker='o', linestyle='-', color='r', label='heap-sort')
plt.plot(data_size, merge_sort, marker='o', linestyle='-', color='g', label='merge-sort')
plt.plot(data_size, shell_sort, marker='o', linestyle='-', color='y', label='shell-sort')

plt.plot(data_size, counting_sort, marker='o', linestyle='-', color='black', label='counting-sort')
plt.plot(data_size, radix_sort, marker='o', linestyle='-', color='aqua', label='radix-sort')
plt.plot(data_size, flash_sort, marker='o', linestyle='-', color='pink', label='flash-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện số phép so sánh trên tập dữ liệu sắp xếp giảm dần (Reversed)")
plt.xlabel("Input")
plt.ylabel("Comparisons")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/comparison/fast/rev.png', dpi=300)
plt.show()

# %% [markdown]
# ## Các thuật toán sắp xếp chậm (Bubble sort, Insertion sort, Shaker sort)

# %%
##Bubble - Shaker hoàn toàn trùng nhau
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Randomize')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Comparisons']
insertion_sort = filtered_data_insertion['Comparisons']
selection_sort = filtered_data_selection['Comparisons']
shaker_sort = filtered_data_shaker['Comparisons']

plt.plot(data_size, bubble_sort, marker='o', linestyle='-', color='b', label='bubble-sort')
plt.plot(data_size, insertion_sort, marker='o', linestyle='-', color='r', label='insertion-sort')
plt.plot(data_size, shaker_sort, marker='o', linestyle='dashed', color='y', label='shaker-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện số phép so sánh trên tập dữ liệu ngẫu nhiên (Randomize)")
plt.xlabel("Input")
plt.ylabel("Comparisons")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/comparison/slow/random.png', dpi=300)
plt.show()

# %%
##Bubble - Shaker hoàn toàn trùng nhau
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Nearly sorted')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Comparisons']
insertion_sort = filtered_data_insertion['Comparisons']
selection_sort = filtered_data_selection['Comparisons']
shaker_sort = filtered_data_shaker['Comparisons']

plt.plot(data_size, bubble_sort, marker='o', linestyle='-', color='b', label='bubble-sort')
plt.plot(data_size, insertion_sort, marker='o', linestyle='-', color='r', label='insertion-sort')
plt.plot(data_size, shaker_sort, marker='o', linestyle='dashed', color='y', label='shaker-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện số phép so sánh trên tập dữ liệu gần như đã sắp xếp (Nearly sorted)")
plt.xlabel("Input")
plt.ylabel("Comparisons")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/comparison/slow/nsorted.png', dpi=300)
plt.show()

# %%
##Bubble - Shaker hoàn toàn trùng nhau
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Sorted')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Comparisons']
insertion_sort = filtered_data_insertion['Comparisons']
selection_sort = filtered_data_selection['Comparisons']
shaker_sort = filtered_data_shaker['Comparisons']

plt.plot(data_size, bubble_sort, marker='o', linestyle='-', color='b', label='bubble-sort')
plt.plot(data_size, insertion_sort, marker='o', linestyle='-', color='r', label='insertion-sort')
plt.plot(data_size, shaker_sort, marker='o', linestyle='dashed', color='y', label='shaker-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện số phép so sánh trên tập dữ liệu đã sắp xếp (Sorted)")
plt.xlabel("Input")
plt.ylabel("Comparisons")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/comparison/slow/sorted.png', dpi=300)
plt.show()

# %%
##Bubble - Shaker hoàn toàn trùng nhau
plt.figure(figsize=(12, 8))
filtered_data_bubble = data[
    (data['Algorithm'] == 'bubble-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_insertion = data[
    (data['Algorithm'] == 'insertion-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_selection = data[
    (data['Algorithm'] == 'selection-sort') & (data['Data Order'] == 'Reversed')
]
filtered_data_shaker = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Reversed')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
bubble_sort = filtered_data_bubble['Comparisons']
insertion_sort = filtered_data_insertion['Comparisons']
selection_sort = filtered_data_selection['Comparisons']
shaker_sort = filtered_data_shaker['Comparisons']

plt.plot(data_size, bubble_sort, marker='o', linestyle='-', color='b', label='bubble-sort')
plt.plot(data_size, insertion_sort, marker='o', linestyle='-', color='r', label='insertion-sort')
plt.plot(data_size, shaker_sort, marker='o', linestyle='dashed', color='y', label='shaker-sort')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện số phép so sánh trên tập dữ liệu (Reversed)")
plt.xlabel("Input")
plt.ylabel("Comparisons")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/comparison/slow/rev.png', dpi=300)
plt.show()

# %% [markdown]
# ## Thuật toán Selection sort

# %%
plt.figure(figsize=(12, 8))
filtered_data_rand = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Randomize')
]
filtered_data_nsorted = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Nearly sorted')
]
filtered_data_sorted = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Sorted')
]
filtered_data_rev = data[
    (data['Algorithm'] == 'shaker-sort') & (data['Data Order'] == 'Reversed')
]


# input data
data_size = [10000, 30000, 50000, 100000, 300000, 500000]
rand_data = filtered_data_rand['Comparisons']
nsorted_data = filtered_data_nsorted['Comparisons']
sorted_data = filtered_data_sorted['Comparisons']
rev_data = filtered_data_rev['Comparisons']

plt.plot(data_size, rand_data, marker='o', linestyle='-', color='b', label='Random')
plt.plot(data_size, nsorted_data, marker='o', linestyle='-', color='r', label='Nearly sorted')
plt.plot(data_size, sorted_data, marker='o', linestyle='-', color='g', label='Sorted')
plt.plot(data_size, rev_data, marker='o', linestyle='-', color='y', label='Reversed')


# Thêm tiêu đề và nhãn
plt.title("Biểu đồ thể hiện số phép so sánh trên các tập dữ liệu của thuật toán Selection sort")
plt.xlabel("Input")
plt.ylabel("Comparisons")
plt.legend()  # Hiển thị chú thích

# Hiển thị biểu đồ

plt.savefig('./img/comparison/slow/selection.png', dpi=300)
plt.show()
